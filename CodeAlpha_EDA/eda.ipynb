# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample dataset
data = {
    "Age": [18, 20, 22, 20, 19, 23, 21],
    "Marks": [65, 70, 75, 80, 60, 85, 78],
    "Gender": ["F", "M", "F", "M", "F", "M", "F"]
}

df = pd.DataFrame(data)

# 1. View first rows
print("First 5 Rows:\n", df.head())

# 2. Data structure
print("\nData Info:")
print(df.info())

# 3. Statistical summary
print("\nStatistical Summary:\n", df.describe())

# 4. Check missing values
print("\nMissing Values:\n", df.isnull().sum())

# 5. Simple trend check using plot
plt.scatter(df["Age"], df["Marks"])
plt.xlabel("Age")
plt.ylabel("Marks")
plt.title("Age vs Marks")
plt.show()
# Out:
# First 5 Rows:
#     Age  Marks Gender
# 0   18     65      F
# 1   20     70      M
# 2   22     75      F
# 3   20     80      M
# 4   19     60      F
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     7 non-null      int64
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes
# None
#
# Statistical Summary:
#               Age      Marks
# count   7.000000   7.000000
# mean   20.428571  73.285714
# std     1.718249   8.788521
# min    18.000000  60.000000
# 25%    19.500000  67.500000
# 50%    20.000000  75.000000
# 75%    21.500000  79.000000
# max    23.000000  85.000000
#
# Missing Values:
#  Age       0
# Marks     0
# Gender    0
# dtype: int64
